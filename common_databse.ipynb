# %%
# import requests
# import pandas as pd
# company_name = 'AAPL'
# #company name can be changed here
# api_key = '08e2d2a138dba992cc772bd27479aade'
# #every account will have a different api key
# Bs = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company_name}?limit=5&apikey={api_key}').json()

# Bs = pd.DataFrame.from_dict(Bs)

# print(Bs.columns)
# #printing to check all the columns
# Bs_columns = ['date', 
#        'cashAndCashEquivalents', 'shortTermInvestments',
#        'cashAndShortTermInvestments', 'netReceivables', 'inventory',
#        'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
#        'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
#        'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
#        'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
#        'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
#        'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
#        'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
#        'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
#        'otherLiabilities', 'totalLiabilities', 'commonStock',
#        'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
#        'totalDebt', 'netDebt']

# Bs = Bs[Bs_columns]
# Bs = Bs.T
# #We are transposing it
# Bs.columns = Bs.iloc[0]
# #header change made the first line, to be the header
# Bs =Bs.iloc[1:]
# #printing from the first line
# print(Bs)

# %%
# import requests
# import pandas as pd
# api_key = '08e2d2a138dba992cc772bd27479aade'
# screen = requests.get(f'https://financialmodelingprep.com/api/v3/stock-screener?marketCapMoreThan=1000000000&sector=Technology&exchange=NASDAQ&limit=10&apikey={api_key}').json()
# #a method to filter out a certain companies on basis of certain parameters , the parameters are seperated by end
# #v3 is the version of the api that we are using.
# #print(screen)

# values = []
# for item in screen:
#   values.append(item['symbol'])

# #print(tickers)
# #this will print the list of the companies as the symbol was used to give there name

# company_list = {} 
# for item in values:
#   BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{item}?limit=1&apikey={api_key}').json()
#   company_list[item] = BS[0]
#   #extracting the first element from the balance sheet!

 
# BS_industry = pd.DataFrame.from_dict(company_list)
# BS_industry

# #if you are not on google collab then you need to use the print statement as well.

# BS_our_Columns = ['date', 
#        'cashAndCashEquivalents', 'shortTermInvestments',
#        'cashAndShortTermInvestments', 'netReceivables', 'inventory',
#        'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
#        'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
#        'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
#        'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
#        'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
#        'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
#        'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
#        'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
#        'otherLiabilities', 'totalLiabilities', 'commonStock',
#        'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
#        'totalDebt', 'netDebt']

#        #removing the unnecssary columns

# BS_industry = BS_industry.T
# BS_industry = BS_industry[BS_our_Columns]
# BS_industry = BS_industry.T
# #print(BS_industry)

# BS_industry1 = BS_industry.iloc[1:]/1000000
# #so that we get small values
# BS_industry1 = BS_industry1.T
# BS_industry1['cashAndCashEquivalents'].plot(legend=True, figsize=(15,5))
# #plotting a particular column form the transpose table.


# BS_industry1.T

# %%
#Preparing common balance sheet!
import requests
import pandas as pd
company_name = 'AAPL'
#company name can be changed here
api_key = '08e2d2a138dba992cc772bd27479aade'
#every account will have a different api key
Bs = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company_name}?limit=5&apikey={api_key}').json()

Bs = pd.DataFrame.from_dict(Bs)

print(Bs.columns)
#printing to check all the columns
Bs_columns = ['date', 
       'cashAndCashEquivalents', 'shortTermInvestments',
       'cashAndShortTermInvestments', 'netReceivables', 'inventory',
       'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
       'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
       'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
       'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
       'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
       'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
       'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
       'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
       'otherLiabilities', 'totalLiabilities', 'commonStock',
       'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
       'othertotalStockholdersEquity', 'totalStockholdersEquity',
       'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
       'totalDebt', 'netDebt']

Bs = Bs[Bs_columns]
Bs = Bs.T
#We are transposing it
Bs.columns = Bs.iloc[0]
#header change made the first line, to be the header
Bs =Bs.iloc[1:]
#printing from the first line
total_assets = Bs.iloc[16]
#storing the total assets in a varibale

common_Size = Bs / total_assets
Bs = Bs.T
print(common_Size)
print(Bs)
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate',
#        'period', 'cashAndCashEquivalents', 'shortTermInvestments',
#        'cashAndShortTermInvestments', 'netReceivables', 'inventory',
#        'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
#        'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
#        'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
#        'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
#        'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
#        'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
#        'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
#        'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
#        'otherLiabilities', 'totalLiabilities', 'commonStock',
#        'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
#        'totalDebt', 'netDebt', 'link', 'finalLink'],
#       dtype='object')
# date                                     2020-09-26  ...  2016-09-24
# cashAndCashEquivalents                     0.117374  ...    0.063677
# shortTermInvestments                       0.163411  ...    0.145082
# cashAndShortTermInvestments                0.280785  ...    0.208759
# netReceivables                             0.115611  ...   0.0489732
# inventory                                 0.0125383  ...  0.00662758
# otherCurrentAssets                        0.0347775  ...   0.0257487
# totalCurrentAssets                         0.443712  ...    0.332215
# propertyPlantEquipmentNet                  0.113515  ...   0.0839639
# goodwill                                          0  ...   0.0168301
# intangibleAssets                                  0  ...  0.00996624
# goodwillAndIntangibleAssets                       0  ...   0.0267963
# longTermInvestments                        0.163411  ...    0.529802
# taxAssets                                         0  ...   0.0808832
# otherNonCurrentAssets                      0.131286  ...   0.0272222
# totalNonCurrentAssets                      0.556288  ...    0.667785
# otherAssets                                0.279362  ...           0
# totalAssets                                       1  ...           1
# accountPayables                            0.130588  ...    0.115933
# shortTermDebt                             0.0425116  ...   0.0251954
# taxPayables                                       0  ...           0
# deferredRevenue                           0.0205102  ...   0.0251177
# otherCurrentLiabilities                    0.131786  ...   0.0284625
# totalCurrentLiabilities                    0.325396  ...      0.2456
# longTermDebt                               0.304633  ...    0.234474
# deferredRevenueNonCurrent                         0  ...  0.00910826
# deferredTaxLiabilitiesNonCurrent                  0  ...           0
# otherNonCurrentLiabilities                0.0812627  ...     0.11214
# totalNonCurrentLiabilities                  0.47287  ...    0.355723
# otherLiabilities                                  0  ...           0
# totalLiabilities                           0.798267  ...    0.601322
# commonStock                                 0.15678  ...   0.0971475
# retainedEarnings                          0.0462073  ...    0.299559
# accumulatedOtherComprehensiveIncomeLoss -0.00125352  ...  0.00197087
# othertotalStockholdersEquity                      0  ... -0.00167866
# totalStockholdersEquity                    0.201733  ...    0.398678
# totalLiabilitiesAndStockholdersEquity             1  ...           1
# totalInvestments                           0.326823  ...    0.674885
# totalDebt                                  0.347145  ...    0.259669
# netDebt                                    0.229771  ...    0.195992
#
# [39 rows x 5 columns]
#            cashAndCashEquivalents  ...      netDebt
# date                               ...
# 2020-09-26            38016000000  ...  74420000000
# 2019-09-28            48844000000  ...  59203000000
# 2018-09-29            25913000000  ...  88570000000
# 2017-09-30            20289000000  ...  95391000000
# 2016-09-24            20484000000  ...  63048000000
#
# [5 rows x 39 columns]
